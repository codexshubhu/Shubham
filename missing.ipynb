# %%
import pandas as pd
import numpy as np
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-463b5506-808a-4875-9a5a-8a84a312be3f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-463b5506-808a-4875-9a5a-8a84a312be3f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel('Iris.xlsx')

print("Original Dataset:")
print(df.head())

df.loc[2, 'SepalLengthCm'] = np.nan
df.loc[5, 'PetalLengthCm'] = np.nan
df.loc[8, 'SepalWidthCm'] = np.nan

print("\nDataset with Missing Values:")
print(df.head(10))


print("\nMissing Values in Dataset:")
print(df.isnull().sum())


drop_rows = df.dropna()

print("\nDataset after Dropping Rows:")
print(drop_rows.head())


drop_columns = df.dropna(axis=1)

print("\nDataset after Dropping Columns:")
print(drop_columns.head())




imputed_df = df.copy()


imputed_df['SepalLengthCm'].fillna(
    imputed_df['SepalLengthCm'].mean(),
    inplace=True
)


imputed_df['PetalLengthCm'].fillna(
    imputed_df['PetalLengthCm'].median(),
    inplace=True
)

imputed_df['SepalWidthCm'].fillna(
    imputed_df['SepalWidthCm'].mean(),
    inplace=True
)

print("\nDataset after Mean/Median Imputation:")
print(imputed_df.head(10))


print("\nMissing Values after Imputation:")
print(imputed_df.isnull().sum())
# Out:
# Original Dataset:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
# Dataset with Missing Values:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            NaN           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# ...
